# %%
import os
import re
import pickle
import json
import gzip
import multiprocessing as mp
import nltk
from nltk.corpus import words

# %%
nltk.download('words')
# Out:
# [nltk_data] Downloading package words to
# [nltk_data]     /home/liufengyuan/nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_AMAZON_FASHION.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Arts_Crafts_and_Sewing.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Automotive.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Books.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_CDs_and_Vinyl.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Cell_Phones_and_Accessories.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Clothing_Shoes_and_Jewelry.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Digital_Music.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Electronics.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Grocery_and_Gourmet_Food.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Home_and_Kitchen.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Industrial_and_Scientific.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Kindle_Store.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Movies_and_TV.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Office_Products.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Patio_Lawn_and_Garden.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Pet_Supplies.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Sports_and_Outdoors.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Tools_and_Home_Improvement.json.gz --no-check-certificate
# !wget -P /data/liufengyuan/NLPinFinance/Data https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Toys_and_Games.json.gz --no-check-certificate
# Out:
# --2023-01-14 03:17:18--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_AMAZON_FASHION.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 33023658 (31M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_AMAZON_FASHION.json.gz’
#
# meta_AMAZON_FASHION 100%[===================>]  31.49M  8.14MB/s    in 3.9s
#
# 2023-01-14 03:17:23 (8.14 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_AMAZON_FASHION.json.gz’ saved [33023658/33023658]
#
# --2023-01-14 03:17:23--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Arts_Crafts_and_Sewing.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 133361326 (127M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Arts_Crafts_and_Sewing.json.gz’
#
# meta_Arts_Crafts_an 100%[===================>] 127.18M  13.1MB/s    in 11s
#
# 2023-01-14 03:17:35 (11.4 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Arts_Crafts_and_Sewing.json.gz’ saved [133361326/133361326]
#
# --2023-01-14 03:17:35--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Automotive.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1588716032 (1.5G) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Automotive.json.gz’
#
# meta_Automotive.jso 100%[===================>]   1.48G  13.0MB/s    in 1m 57s
#
# 2023-01-14 03:19:33 (12.9 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Automotive.json.gz’ saved [1588716032/1588716032]
#
# --2023-01-14 03:19:34--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Books.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1219104464 (1.1G) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Books.json.gz’
#
# meta_Books.json.gz  100%[===================>]   1.13G  5.29MB/s    in 6m 40s
#
# 2023-01-14 03:26:15 (2.91 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Books.json.gz’ saved [1219104464/1219104464]
#
# --2023-01-14 03:26:15--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_CDs_and_Vinyl.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 161716387 (154M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_CDs_and_Vinyl.json.gz’
#
# meta_CDs_and_Vinyl. 100%[===================>] 154.22M  6.10MB/s    in 20s
#
# 2023-01-14 03:26:36 (7.70 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_CDs_and_Vinyl.json.gz’ saved [161716387/161716387]
#
# --2023-01-14 03:26:36--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Cell_Phones_and_Accessories.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 360006372 (343M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Cell_Phones_and_Accessories.json.gz’
#
# meta_Cell_Phones_an 100%[===================>] 343.33M  13.1MB/s    in 28s
#
# 2023-01-14 03:27:04 (12.4 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Cell_Phones_and_Accessories.json.gz’ saved [360006372/360006372]
#
# --2023-01-14 03:27:05--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Clothing_Shoes_and_Jewelry.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1565302499 (1.5G) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Clothing_Shoes_and_Jewelry.json.gz’
#
# meta_Clothing_Shoes 100%[===================>]   1.46G  2.89MB/s    in 8m 56s
#
# 2023-01-14 03:36:02 (2.78 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Clothing_Shoes_and_Jewelry.json.gz’ saved [1565302499/1565302499]
#
# --2023-01-14 03:36:02--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Digital_Music.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 12367273 (12M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Digital_Music.json.gz’
#
# meta_Digital_Music. 100%[===================>]  11.79M  5.23MB/s    in 2.3s
#
# 2023-01-14 03:36:06 (5.23 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Digital_Music.json.gz’ saved [12367273/12367273]
#
# --2023-01-14 03:36:06--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Electronics.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1198601797 (1.1G) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Electronics.json.gz’
#
# meta_Electronics.js 100%[===================>]   1.12G  13.2MB/s    in 88s
#
# 2023-01-14 03:37:35 (12.9 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Electronics.json.gz’ saved [1198601797/1198601797]
#
# --2023-01-14 03:37:35--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Grocery_and_Gourmet_Food.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 109586529 (105M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Grocery_and_Gourmet_Food.json.gz’
#
# meta_Grocery_and_Go 100%[===================>] 104.51M  12.4MB/s    in 9.6s
#
# 2023-01-14 03:37:46 (10.8 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Grocery_and_Gourmet_Food.json.gz’ saved [109586529/109586529]
#
# --2023-01-14 03:37:46--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Home_and_Kitchen.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1758091047 (1.6G) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Home_and_Kitchen.json.gz’
#
# meta_Home_and_Kitch 100%[===================>]   1.64G  13.3MB/s    in 2m 11s
#
# 2023-01-14 03:39:57 (12.8 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Home_and_Kitchen.json.gz’ saved [1758091047/1758091047]
#
# --2023-01-14 03:39:57--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Industrial_and_Scientific.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 83600786 (80M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Industrial_and_Scientific.json.gz’
#
# meta_Industrial_and 100%[===================>]  79.73M  13.4MB/s    in 7.7s
#
# 2023-01-14 03:40:06 (10.4 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Industrial_and_Scientific.json.gz’ saved [83600786/83600786]
#
# --2023-01-14 03:40:06--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Kindle_Store.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 100659809 (96M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Kindle_Store.json.gz’
#
# meta_Kindle_Store.j 100%[===================>]  96.00M  4.18MB/s    in 30s
#
# 2023-01-14 03:40:37 (3.17 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Kindle_Store.json.gz’ saved [100659809/100659809]
#
# --2023-01-14 03:40:38--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Movies_and_TV.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 104749005 (100M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Movies_and_TV.json.gz’
#
# meta_Movies_and_TV. 100%[===================>]  99.90M  13.2MB/s    in 9.2s
#
# 2023-01-14 03:40:48 (10.8 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Movies_and_TV.json.gz’ saved [104749005/104749005]
#
# --2023-01-14 03:40:48--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Office_Products.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 511852905 (488M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Office_Products.json.gz’
#
# meta_Office_Product 100%[===================>] 488.14M  13.1MB/s    in 39s
#
# 2023-01-14 03:41:28 (12.6 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Office_Products.json.gz’ saved [511852905/511852905]
#
# --2023-01-14 03:41:28--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Patio_Lawn_and_Garden.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 422825090 (403M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Patio_Lawn_and_Garden.json.gz’
#
# meta_Patio_Lawn_and 100%[===================>] 403.24M  13.1MB/s    in 32s
#
# 2023-01-14 03:42:01 (12.5 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Patio_Lawn_and_Garden.json.gz’ saved [422825090/422825090]
#
# --2023-01-14 03:42:01--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Pet_Supplies.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 284871978 (272M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Pet_Supplies.json.gz’
#
# meta_Pet_Supplies.j 100%[===================>] 271.67M  3.22MB/s    in 73s
#
# 2023-01-14 03:43:16 (3.70 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Pet_Supplies.json.gz’ saved [284871978/284871978]
#
# --2023-01-14 03:43:16--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Sports_and_Outdoors.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 523414200 (499M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Sports_and_Outdoors.json.gz’
#
# meta_Sports_and_Out 100%[===================>] 499.17M  13.0MB/s    in 40s
#
# 2023-01-14 03:43:56 (12.5 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Sports_and_Outdoors.json.gz’ saved [523414200/523414200]
#
# --2023-01-14 03:43:57--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Tools_and_Home_Improvement.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 1062814268 (1014M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Tools_and_Home_Improvement.json.gz’
#
# meta_Tools_and_Home 100%[===================>]   1014M  3.04MB/s    in 7m 2s
#
# 2023-01-14 03:51:00 (2.40 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Tools_and_Home_Improvement.json.gz’ saved [1062814268/1062814268]
#
# --2023-01-14 03:51:00--  https://jmcauley.ucsd.edu/data/amazon_v2/metaFiles2/meta_Toys_and_Games.json.gz
# Resolving jmcauley.ucsd.edu (jmcauley.ucsd.edu)... 137.110.160.73
# Connecting to jmcauley.ucsd.edu (jmcauley.ucsd.edu)|137.110.160.73|:443... connected.
# WARNING: cannot verify jmcauley.ucsd.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 808563982 (771M) [application/x-gzip]
# Saving to: ‘/data/liufengyuan/NLPinFinance/Data/meta_Toys_and_Games.json.gz’
#
# meta_Toys_and_Games 100%[===================>] 771.11M  13.1MB/s    in 60s
#
# 2023-01-14 03:52:01 (12.8 MB/s) - ‘/data/liufengyuan/NLPinFinance/Data/meta_Toys_and_Games.json.gz’ saved [808563982/808563982]

# %%
data = []
with gzip.open('/data/liufengyuan/NLPinFinance/Data/meta_AMAZON_FASHION.json.gz') as f:
    for l in f:
        data.append(json.loads(l.strip()))

# %%
print(len(data))
# Out:
# 186637

# %%
count = 0
for i in range(20):
    if 'feature' in data[i].keys():
        count += 1

# %%
count
# Out:
# 14

# %%
print(data[0].keys())
# Out:
# dict_keys(['title', 'brand', 'feature', 'rank', 'date', 'asin', 'imageURL', 'imageURLHighRes'])

# %%
print(data[1].keys())
# Out:
# dict_keys(['title', 'rank', 'date', 'asin', 'imageURL', 'imageURLHighRes'])

# %%
f_save = open('/data/liufengyuan/NLPinFinance/Filtered Data/AMAZON_FASHION.pkl', 'rb')
file_read = pickle.load(f_save)
f_save.close()

# %%
output = file_read[10]
output
# Out:
# {'asin': 'B0000AWYXK',
#  'title': '14k White Gold 8mm Half Round Plain Wedding Band',
#  'feature': ['Package Dimensions:\n                    \n2 x 2 x 1.9 inches',
#   'Shipping Weight:\n                    \n3.2 ounces'],
#  'description': ['With its smooth surface and high polish, this white gold wedding band is a stylish start to any marriage. The width of the ring is slightly rounded and the edges are straight, making the band appear more substantial while allowing it to sit comfortably. 14k gold is a durable fine metal, meaning this wedding band will last as long as your love.',
#   '',
#   '',
#   '',
#   'Discover the Amazon Curated Collection of fine and fashion jewelry. The expansive selection of high-quality jewelry featured in the Amazon Curated Collection offers everyday values that range from precious gemstone and diamond pieces to the latest fashion designs.',
#   'This hand-selected assortment features an array of diamond, gemstone and precious metal designs that receive a quality inspection, including from Amazons staff graduate gemologist, to ensure they meet Amazons high standards. All diamonds featured in the Amazon Curated Collection are certified by our suppliers to be conflict free, and IGI, GIA, or AGS certifications are provided on white diamonds of .75 carats or larger on all stud earrings, rings, and pendant necklaces.',
#   'Pieces from the Amazon Curated Collection come packaged in a custom box, making them wonderful gifts. In addition, we offer free one-day shipping within the continental US on items over $500. International shipping options for friends and family overseas are available for an additional fee.',
#   'The Amazon Curated Collection offers a specialized customer service team that is available seven days a week to answer any product questions before, during or after the purchase. If youre not satisfied for any reason, you will receive a full refund and free return shipping within the US if you return your purchase within 30 days.',
#   'Find a special gift for a loved one or a beautiful piece that complements your personal style with jewelry from the Amazon Curated Collection.',
#   'Gold Purity',
#   "The purity of gold is measured in karats. Pure gold measures 24 karats but is too soft in this state to be used effectively in jewelry. So it is alloyed with other metals--silver, copper, nickel, and zinc--to increase its strength and durability. Common measurements once the alloy is added are 18 karat (75% gold), 14 karat (58%), and 10 karat (47.7%). In the United States, the legal karat limit for the metal to still be considered gold is 10 karats. A higher karat measurement in gold content indicates a greater value of the jewelry piece. Gold jewelry should always be stamped with the karat mark, either 18k, 750 (European marking for 18k), 14k, 585 (European marking for 14k), or 10k. In addition, to assure its quality, the piece should be stamped with the manufacturer's trademark or country of origin.",
#   'Gold Color',
#   'The color of gold may vary based off of the type of metal alloy included and the percentage of the metal alloy used. Most commonly, gold is available in yellow, white and rose coloring.',
#   'Yellow gold is the most common color and is usually alloyed with silver and copper. Yellow and white gold are similar in strength and malleability, making them perfect for jewelry that is worn daily.',
#   'White gold is alloyed with nickel, copper, and zinc--and while it looks similar to platinum, it has vastly different properties.',
#   'Rose-colored gold is alloyed with copper and is often used to accent white or yellow gold. The saturation of color varies from piece to piece and according to gold content.',
#   'Caring For Your Gold Jewelry',
#   'To keep gold shining and scratch-free, avoid contact with chlorine and other harsh chemicals. Do not wear jewelry during rough work and be sure to store it in a fabric-lined jewelry box or pouch. To clean gold jewelry, use warm water, a mild soap, and a soft bristled brush, if needed.',
#   ''],
#  'imageURLHighRes': ['https://images-na.ssl-images-amazon.com/images/I/41BXKABYFVL.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/31CoVdns-FL.jpg',
#   'https://images-na.ssl-images-amazon.com/images/I/31CoVdns-FL.jpg']}

# %%
results = re.compile(r'#[]', re.S)
results2 = re.compile(r'<[|\n;#_\'(){}*-<>a-zA-Z0-9.?/&=:    " ]*', re.S)

# %%
# sentence = output['title']
# output = re.findall(pat, sentence.lower())
wordlist = {}
temp_output = []
pat = '[a-zA-Z]+'
features = output['feature']
for fea in features:
    #print(fea)
    #fea = re.sub(results, '', fea)
    fea = re.sub(results2, '', fea)
    print(fea)
    temp = re.findall(pat, fea)
    print(temp)
    temp_output.extend(temp)
# Out:
# Shimmer Anne Shine Clip On Costume/Halloween Cat Ears
# ['Shimmer', 'Anne', 'Shine', 'Clip', 'On', 'Costume', 'Halloween', 'Cat', 'Ears']
# You can return this item for any reason and get a full refund: no shipping charges. The item must be returned in new and unused condition.
# ['You', 'can', 'return', 'this', 'item', 'for', 'any', 'reason', 'and', 'get', 'a', 'full', 'refund', 'no', 'shipping', 'charges', 'The', 'item', 'must', 'be', 'returned', 'in', 'new', 'and', 'unused', 'condition']
# Read the full returns policy
# ['Read', 'the', 'full', 'returns', 'policy']
# Go to Your Orders to start the return
# ['Go', 'to', 'Your', 'Orders', 'to', 'start', 'the', 'return']
# Print the return shipping label
# ['Print', 'the', 'return', 'shipping', 'label']
# Ship it!
# ['Ship', 'it']
# Package Dimensions:
#
# 3.8 x 3 x 0.8 inches
# ['Package', 'Dimensions', 'x', 'x', 'inches']
# Shipping Weight:
#
# 0.64 ounces (View shipping rates and policies)
# ['Shipping', 'Weight', 'ounces', 'View', 'shipping', 'rates', 'and', 'policies']

# %%
emoji_pattern = re.compile(
    u"(\ud83d[\ude00-\ude4f])|"  # emoticons
    u"(\ud83c[\udf00-\uffff])|"  # symbols & pictographs (1 of 2)
    u"(\ud83d[\u0000-\uddff])|"  # symbols & pictographs (2 of 2)
    u"(\ud83d[\ude80-\udeff])|"  # transport & map symbols
    u"(\ud83c[\udde0-\uddff])"  # flags (iOS)
    "+", flags=re.UNICODE)

# %%
import re

# 定义tokenize方法：
def tokenize(text):
    # 定义分割符，该变量作为超参数，可以根据情况删减 <[|\n;#_\'(){}*-<>a-zA-Z0-9.?/&=:
    filters = ['\|', '\?', '\{', '\}', '-', '\$', '\'', '\"', '\+', '\*', '!', '', '', ';', ':', '；','#', '%', '&', '\t', '\n', '\x97', '\x96', ',', '\(', '\)','\.']

    # 运用正则进行分词:
    # 将网页内容如<>以及分隔符全部替代为空格
    text = re.sub("<.*?>", " ", text, flags=re.S)
    # 将n't转换为not
    text = re.sub("n't", " not", text, flags=re.S)
    # 将感叹号单独分割出来
    #text = re.sub("(\w)!", "\g<1> !", text, flags=re.S)
    # 去掉一些特殊情况
    text = re.sub("\[download PDF version\]", " ", text, flags=re.S)
    text = re.sub("(View shipping rates and policies)", " ", text, flags=re.S)
    # 将分隔符全部替代为空格
    text = re.sub("|".join(filters), " ", text, flags=re.S)
    #text = emoji_pattern.sub(r'', text)
    # 运用strip()返回移除字符串头尾指定的字符（默认为空格或换行符）生成的新字符串:并转换为小写：
    result = [i.strip().lower() for i in text.split()]
    return result

# %%
def tokenize(text):
    # 运用正则进行分词:
    # 将网页内容如<>以及分隔符全部替代为空格
    text = re.sub("<.*?>", " ", text, flags=re.S)
    # 将n't转换为not
    text = re.sub("n't", " not", text, flags=re.S)
    # 将感叹号单独分割出来
    #text = re.sub("(\w)!", "\g<1> !", text, flags=re.S)
    # 去掉一些特殊情况
    text = re.sub("\[download PDF version\]", " ", text, flags=re.S)
    text = re.sub("(View shipping rates and policies)", " ", text, flags=re.S)
    # 将分隔符全部替代为空格
    #text = emoji_pattern.sub(r'', text)
    # 运用strip()返回移除字符串头尾指定的字符（默认为空格或换行符）生成的新字符串:并转换为小写：
    result = [i.strip().lower() for i in text.split()]
    return result

# %%
features = output['feature']
for fea in features:
    #print(fea)
    #fea = re.sub(results, '', fea)
    #fea = re.sub(results2, '', fea)
    print(fea)
    temp = tokenize(fea)
    print(temp)
# Out:
# Shimmer Anne Shine Clip On Costume/Halloween Cat Ears
# ['shimmer', 'anne', 'shine', 'clip', 'on', 'costume/halloween', 'cat', 'ears']
# You can return this item for any reason and get a full refund: no shipping charges. The item must be returned in new and unused condition.
# ['you', 'can', 'return', 'this', 'item', 'for', 'any', 'reason', 'and', 'get', 'a', 'full', 'refund', 'no', 'shipping', 'charges', 'the', 'item', 'must', 'be', 'returned', 'in', 'new', 'and', 'unused', 'condition']
# Read the full returns policy
# ['read', 'the', 'full', 'returns', 'policy']
# Go to Your Orders to start the return
# ['go', 'to', 'your', 'orders', 'to', 'start', 'the', 'return']
# Print the return shipping label
# ['print', 'the', 'return', 'shipping', 'label']
# Ship it!
# ['ship', 'it', '!']
# Package Dimensions:
#
# 3.8 x 3 x 0.8 inches
# ['package', 'dimensions', '3', '8', 'x', '3', 'x', '0', '8', 'inches']
# Shipping Weight:
#
# 0.64 ounces (View shipping rates and policies)
# ['shipping', 'weight', '0', '64', 'ounces']

# %%
filenames = os.listdir(r'/data/liufengyuan/NLPinFinance/Filtered Data')
wordlist = {}
pat = '[a-zA-Z]+'
total = 0
out = False
for name in filenames:
    f_save = open('/data/liufengyuan/NLPinFinance/Filtered Data/' + name, 'rb')
    print(name)
    file_read = pickle.load(f_save)
    f_save.close()
    for item in file_read:
        total += 1
        sentence = item['title']
        #print(sentence)
        #output = re.findall(pat, sentence.lower())
        #sentence = re.sub(results2, '', sentence)
        #output = tokenize(sentence.lower())
        output = re.findall(pat, sentence.lower())
        #output = []
        features = item['feature']
        for fea in features:
        #    if '#A' in fea:
        #        print(fea)
        #        out = True
        #        break
            fea = re.sub(results2, '', fea)
            #output.extend(tokenize(fea.lower()))
            output.extend(re.findall(pat, fea.lower()))
        for word in output:
            if word in wordlist.keys():
                wordlist[word] += 1
            else:
                wordlist[word] = 1
        #if out == True:
        #    out = False
        #    break
    #break
    print(total)
wordlist
# Out:
# Cell_Phones_and_Accessories.pkl
# 282198
# Office_Products.pkl
# 417298
# Movies_and_TV.pkl
# 417351
# Patio_Lawn_and_Garden.pkl
# 529729
# Clothing_Shoes_and_Jewelry.pkl
# 2043156
# Electronics.pkl
# 2463881
# Industrial_and_Scientific.pkl
# 2489700
# Kindle_Store.pkl
# 2489700
# Digital_Music.pkl
# 2489723
# Home_and_Kitchen.pkl
# 3026039
# Sports_and_Outdoors.pkl
# 3391802
# CDs_and_Vinyl.pkl
# 3391873
# Books.pkl
# 3392839
# Arts_Crafts_and_Sewing.pkl
# 3505092
# Toys_and_Games.pkl
# 3747531
# Grocery_and_Gourmet_Food.pkl
# 3755740
# AMAZON_FASHION.pkl
# 3764050
# Pet_Supplies.pkl
# 3872506
# Automotive.pkl
# 4291352
# Tools_and_Home_Improvement.pkl
# 4527550
# {'juicy': 2425,
#  'couture': 5996,
#  'durable': 386393,
#  'layers': 24316,
#  'crest': 3382,
#  'case': 920178,
#  'for': 5164854,
#  'iphone': 333934,
#  'hot': 92658,
#  'pink': 150148,
#  'free': 564159,
#  'screen': 399438,
#  'protector': 170327,
#  'lightweight': 202922,
#  'polycarbonate': 37521,
#  'hard': 211962,
#  'shell': 96690,
#  'two': 294890,
#  'piece': 227982,
#  'snap': 116891,
#  'together': 35636,
#  'design': 740478,
#  'full': 601355,
#  'access': 178057,
#  'to': 4362383,
#  'all': 893512,
#  'controls': 47226,
#  'hi': 27417,
#  'res': 12744,
#  'image': 647888,
#  'on': 1540279,
#  'silver': 380863,
#  'elegant': 84555,
#  'butterfly': 26006,
#  'foot': 73719,
#  'ankle': 42748,
#  'chain': 131563,
#  'summer': 47431,
#  'beach': 59584,
#  'bracelet': 114945,
#  'evil': 5234,
#  'eye': 54287,
#  'charm': 74027,
#  'item': 485706,
#  'is': 1767038,
#  'brand': 332590,
#  'new': 936440,
#  'see': 128896,
#  'description': 47592,
#  'details': 66014,
#  'we': 371118,
#  'ship': 166408,
#  'as': 568533,
#  'fast': 116961,
#  'can': 740392,
#  'but': 123917,
#  'please': 307079,
#  'allow': 72357,
#  'days': 191701,
#  'delivery': 42592,
#  'sole': 338165,
#  'trader': 188,
#  'at': 535607,
#  'apple': 133234,
#  's': 2514313,
#  'protective': 106673,
#  'metal': 267605,
#  'swarovski': 23462,
#  'diamond': 90287,
#  'skin': 125765,
#  'cover': 451512,
#  'in': 3173647,
#  'wine': 40213,
#  'red': 246924,
#  'fit': 682024,
#  'or': 1640304,
#  'shelter': 3018,
#  'your': 2031986,
#  'dust': 99538,
#  'shock': 93074,
#  'scratches': 130213,
#  'and': 8338388,
#  'bumps': 33365,
#  'unique': 192609,
#  'special': 137830,
#  'style': 541546,
#  'different': 117893,
#  'with': 3864343,
#  'the': 5283119,
#  'other': 302113,
#  'one': 505805,
#  'vip': 1314,
#  'watch': 201895,
#  'cell': 99979,
#  'phone': 395308,
#  'mobile': 143013,
#  'dual': 140336,
#  'sim': 14485,
#  'standby': 7762,
#  'gb': 130010,
#  'internal': 46681,
#  'memory': 86497,
#  'cam': 8890,
#  'black': 823512,
#  'ring': 190678,
#  'mp': 68786,
#  'player': 42700,
#  'video': 139397,
#  'camera': 175333,
#  'media': 101221,
#  'pda': 3792,
#  'quad': 17943,
#  'band': 122905,
#  'mhz': 25075,
#  'unlocked': 12134,
#  'touchscreen': 17040,
#  'sms': 3708,
#  'mms': 749,
#  'smile': 18156,
#  'protection': 417056,
#  'purple': 77455,
#  'belt': 129731,
#  'clip': 123387,
#  'holster': 46408,
#  'same': 85252,
#  'otterbox': 6900,
#  'ratcheting': 2552,
#  'included': 377069,
#  'oem': 86244,
#  'retail': 51478,
#  'package': 878025,
#  'material': 515677,
#  'low': 209693,
#  'profile': 67978,
#  'construction': 167469,
#  'protect': 132065,
#  'device': 155965,
#  'from': 1123743,
#  'without': 186319,
#  'adding': 17386,
#  'bulk': 33067,
#  'anti': 157565,
#  'slip': 133763,
#  'properties': 17557,
#  'give': 71450,
#  'more': 455337,
#  'grips': 19447,
#  'surfaces': 39344,
#  'static': 30102,
#  'silicone': 163407,
#  'reduces': 38483,
#  'surface': 167655,
#  'makes': 146327,
#  'feel': 109104,
#  'softer': 6777,
#  'minisdesign': 75,
#  'd': 3621245,
#  'bling': 25399,
#  'crystal': 178335,
#  'bow': 37552,
#  'transparent': 140324,
#  'fashionable': 38093,
#  'others': 15576,
#  'precise': 56134,
#  'cut': 178629,
#  'ports': 92735,
#  'features': 262235,
#  'of': 2705950,
#  'dirt': 60930,
#  'resistant': 349459,
#  'pc': 247240,
#  'simple': 90609,
#  'back': 520156,
#  'luxury': 38238,
#  'classical': 3455,
#  'art': 157345,
#  'creative': 32868,
#  'iglaze': 106,
#  'animal': 39651,
#  'graphic': 44104,
#  'slim': 140598,
#  'plastic': 279554,
#  'panda': 5473,
#  'innovative': 21401,
#  'ultra': 152054,
#  'high': 934195,
#  'quality': 878710,
#  'tpu': 64084,
#  'ultimate': 45433,
#  'virtually': 15932,
#  'unnoticeable': 330,
#  'weigh': 2715,
#  'increase': 21987,
#  'coating': 70731,
#  'inside': 147802,
#  'outside': 45536,
#  'scratch': 99363,
#  'quick': 122462,
#  'easy': 806064,
#  'giraffe': 3553,
#  'abs': 50210,
#  'fingerprint': 18663,
#  'film': 68683,
#  'squeegee': 6771,
#  'micro': 95957,
#  'fabric': 318978,
#  'wiping': 2562,
#  'cloth': 94818,
#  'kate': 7050,
#  'spade': 7883,
#  'gs': 15999,
#  'any': 555692,
#  'version': 36255,
#  'close': 103935,
#  'debris': 14821,
#  'fits': 301482,
#  'models': 76571,
#  'layer': 106105,
#  'harder': 3486,
#  'total': 70363,
#  'lg': 94714,
#  'vx': 7320,
#  'dare': 1078,
#  'led': 253918,
#  'car': 198100,
#  'vehicle': 102337,
#  'charger': 134280,
#  'light': 509567,
#  'weight': 1410128,
#  'convenient': 89011,
#  'equal': 4503,
#  'original': 191980,
#  'manufacturer': 121776,
#  'apos': 423,
#  'specifications': 35717,
#  'this': 1471978,
#  'a': 14740565,
#  'reasonable': 2858,
#  'alternative': 16685,
#  'premium': 275935,
#  'charging': 96610,
#  'capabilities': 40424,
#  'integrated': 33869,
#  'regulation': 3109,
#  'chip': 28149,
#  'speed': 100555,
#  'will': 594172,
#  'charge': 69743,
#  'most': 202284,
#  'phones': 39599,
#  'within': 114747,
#  'minutes': 32225,
#  'then': 68919,
#  'switch': 98969,
#  'maintain': 20355,
#  'mode': 58376,
#  'slower': 708,
#  'maintaining': 7776,
#  'keep': 169393,
#  'battery': 259387,
#  'level': 51008,
#  'overcharging': 4858,
#  'it': 861681,
#  'eight': 7808,
#  'coiled': 2723,
#  'cord': 91212,
#  'assassin': 738,
#  'creed': 820,
#  'iii': 19290,
#  'perfectly': 71920,
#  'provide': 125893,
#  'good': 117270,
#  'slot': 37382,
#  'cenior': 1,
#  'world': 69798,
#  'gsm': 21326,
#  'white': 615634,
#  'g': 2671172,
#  'network': 18201,
#  'cards': 94484,
#  'super': 167151,
#  'big': 100235,
#  'keyboard': 52620,
#  'helpful': 2271,
#  'emergency': 16198,
#  'call': 174372,
#  'dial': 86479,
#  'key': 95766,
#  'support': 188880,
#  'sd': 37245,
#  'extend': 10670,
#  'max': 154939,
#  'text': 318453,
#  'messaging': 2260,
#  'e': 2908772,
#  'mail': 12564,
#  'instant': 20184,
#  'aplications': 18,
#  'magnifier': 4365,
#  'facebook': 3914,
#  'calculator': 3132,
#  'currency': 3588,
#  'converter': 13301,
#  'stopwatch': 2664,
#  'factory': 66774,
#  'language': 4207,
#  'english': 13822,
#  'french': 23623,
#  'spanish': 5249,
#  'portuguese': 551,
#  'dimension': 57029,
#  'professional': 87183,
#  'saver': 7986,
#  'htc': 48799,
#  'xv': 2416,
#  'universal': 79057,
#  'size': 1380718,
#  'designed': 339066,
#  'laser': 47802,
#  'clearest': 371,
#  'imported': 563841,
#  'direct': 69063,
#  'japan': 26620,
#  'best': 193858,
#  'you': 1393775,
#  'get': 260734,
#  'superior': 81667,
#  'millionth': 22,
#  'millimeter': 4441,
#  'protects': 96833,
#  'sensitive': 17607,
#  'touch': 222708,
#  'fingerprints': 19108,
#  'damage': 68840,
#  'bubble': 42661,
#  're': 57355,
#  'usable': 5660,
#  'washable': 116661,
#  'be': 682863,
#  'used': 166376,
#  'cleaned': 7132,
#  'pack': 276390,
#  'includes': 422593,
#  'x': 4332456,
#  'inch': 759189,
#  'protectors': 26505,
#  'that': 588515,
#  'must': 139373,
#  'down': 139191,
#  'specific': 32734,
#  'blackberry': 16773,
#  'curve': 9979,
#  'spyder': 2490,
#  'official': 40981,
#  'performance': 342112,
#  'motorola': 35544,
#  'droid': 18826,
#  'equipment': 49738,
#  'dc': 94105,
#  'volt': 26715,
#  'safely': 21086,
#  'using': 131873,
#  'authentic': 62518,
#  'ensure': 120378,
#  'warranty': 351215,
#  'never': 63564,
#  'voided': 351,
#  'use': 563737,
#  'prolong': 3233,
#  'batteries': 73168,
#  'life': 169520,
#  'compare': 9288,
#  'stage': 36486,
#  'charges': 119768,
#  'quickly': 37208,
#  'mid': 73818,
#  'wall': 228133,
#  'home': 233264,
#  'rokr': 60,
#  'ac': 206361,
#  'slowly': 2741,
#  'precisely': 16135,
#  'percent': 53460,
#  'rate': 27360,
#  'i': 651817,
#  'fixed': 51201,
#  'blades': 24343,
#  'razr': 5375,
#  'v': 1026743,
#  'm': 1253717,
#  've': 9496,
#  'vegas': 2004,
#  'pearl': 46493,
#  'flip': 66196,
#  'q': 490579,
#  'usb': 246078,
#  'versions': 6030,
#  'renegade': 883,
#  'samsung': 219693,
#  'travel': 94148,
#  'sph': 1938,
#  'photon': 999,
#  'intercept': 185,
#  'galaxy': 231161,
#  'sgh': 5286,
#  't': 1887489,
#  'suit': 35248,
#  'detachable': 30915,
#  'comes': 194039,
#  'cable': 224513,
#  'technology': 145890,
#  'allows': 148224,
#  'while': 147361,
#  'compact': 75269,
#  'go': 195204,
#  'sgha': 5,
#  'vibrant': 33900,
#  'plus': 214348,
#  'epic': 4028,
#  'reality': 3356,
#  'thrill': 1180,
#  'kit': 211420,
#  'illusion': 4166,
#  'motonav': 27,
#  'tn': 4839,
#  'rapid': 14575,
#  'packaging': 87465,
#  'stylish': 102012,
#  'portable': 81899,
#  'accessory': 69335,
#  'port': 75235,
#  'additional': 60643,
#  'accessories': 122405,
#  'fitquipment': 143,
#  'coverage': 69704,
#  'hd': 120037,
#  'clear': 241192,
#  'compatible': 263487,
#  'perfect': 469492,
#  'definition': 34756,
#  'accuracy': 15185,
#  'sensitivity': 19496,
#  'response': 21506,
#  'keeps': 77085,
#  'which': 152544,
#  'ensures': 51559,
#  'app': 33851,
#  'launch': 3221,
#  'smooth': 128370,
#  'games': 22668,
#  'playing': 19866,
#  'highly': 48101,
#  'effectively': 13757,
#  'tear': 30475,
#  'installation': 201808,
#  'removing': 20279,
#  'aligning': 967,
#  'properly': 9940,
#  'before': 124847,
#  'actual': 39256,
#  'no': 944782,
#  'foam': 95455,
#  'google': 20819,
#  'pixel': 50506,
#  'xl': 124779,
#  'live': 21562,
#  'pedal': 8053,
#  'h': 1799477,
#  'hardness': 19479,
#  'install': 97874,
#  'tempered': 38398,
#  'glass': 239520,
#  'specifically': 39762,
#  'curved': 26071,
#  'thermoforming': 100,
#  'technique': 4791,
#  'bring': 26734,
#  'only': 362175,
#  'real': 73629,
#  'edge': 132372,
#  'amazon': 851662,
#  'optically': 4719,
#  'mm': 727008,
#  'thickness': 43674,
#  'invisible': 15200,
#  'like': 230722,
#  'true': 96288,
#  'grade': 127134,
#  'push': 340884,
#  'easiy': 247,
#  'transparency': 9669,
#  'clarity': 24073,
#  'natural': 159057,
#  'provides': 205536,
#  'flawless': 5689,
#  'nokia': 18391,
#  'lumia': 15189,
#  'smartphone': 36203,
#  'data': 217786,
#  'custom': 169008,
#  'outperforms': 609,
#  'originally': 2788,
#  'manufactured': 76868,
#  'aftermarkets': 45,
#  'connects': 11697,
#  'computer': 56740,
#  'software': 14795,
#  'sold': 105816,
#  'separately': 49869,
#  'phonebook': 701,
#  'internet': 9772,
#  'music': 70629,
#  'ringtones': 491,
#  'calendar': 26490,
#  'long': 388707,
#  'modem': 2608,
#  'view': 675217,
#  'advanced': 42159,
#  'controlled': 9880,
#  'equally': 1817,
#  'by': 977430,
#  'means': 23447,
#  'accurate': 27601,
#  'digitial': 84,
#  'acer': 10748,
#  'iconia': 2331,
#  'tab': 169758,
#  'folding': 33074,
#  'blade': 68926,
#  'complete': 115167,
#  'fraction': 4804,
#  'price': 106490,
#  'an': 402441,
#  'automatic': 43916,
#  'digital': 134241,
#  'slow': 8034,
#  'speeds': 10684,
#  'precision': 55861,
#  'outlast': 1377,
#  'competition': 5665,
#  'shows': 18105,
#  'when': 600234,
#  'correctly': 5901,
#  'turns': 9552,
#  'off': 247308,
#  'eco': 45912,
#  'usa': 343676,
#  'plug': 111088,
#  'vac': 10392,
#  'ma': 49701,
#  'ft': 120108,
#  'items': 187143,
#  'combo': 32991,
#  'zte': 12513,
#  'z': 373808,
#  'amp': 266650,
#  'vines': 1586,
#  'stylus': 62239,
#  'pen': 86904,
#  'stereo': 44079,
#  'earphone': 12977,
#  'headsets': 3315,
#  'through': 93224,
#  'sleek': 39883,
#  'its': 115737,
#  'mold': 30589,
#  'trim': 74120,
#  'trendy': 19964,
#  'reinforced': 44954,
#  'sides': 60666,
#  'durability': 148721,
#  'openings': 25056,
#  'amulet': 3830,
#  'chinese': 16853,
#  'feng': 2190,
#  'shui': 2149,
#  'hand': 381919,
#  'carved': 12496,
#  'lucky': 13027,
#  'jade': 5316,
#  'dragon': 16069,
#  'charms': 23110,
#  'money': 121059,
#  'talisman': 781,
#  'zodiac': 2640,
#  'sign': 34273,
#  'color': 1187079,
#  'may': 165716,
#  'vary': 54318,
#  'could': 21517,
#  'lighter': 17613,
#  'darker': 2327,
#  'than': 154675,
#  'picture': 77800,
#  'purse': 35617,
#  'zipper': 152826,
#  'pull': 80082,
#  'desirable': 821,
#  'way': 106868,
#  'top': 1045449,
#  'loop': 59797,
#  'bottom': 461969,
#  'leaves': 18937,
#  'horse': 16299,
#  'wide': 286835,
#  'pantech': 3225,
#  'burst': 4305,
#  'p': 1197448,
#  'blue': 298678,
#  'opening': 83703,
#  'tool': 84397,
#  'magic': 22152,
#  'soil': 11345,
#  'gift': 407715,
#  'xprt': 144,
#  'mb': 30584,
#  'sprint': 20911,
#  'wrist': 48771,
#  'nexus': 23661,
#  'ii': 45199,
#  'aa': 79082,
#  'lifetime': 130147,
#  'brushed': 43475,
#  'aluminum': 147324,
#  'housing': 29742,
#  'unlimited': 23913,
#  'uses': 53395,
#  'recharges': 1164,
#  'left': 825808,
#  'power': 294747,
#  'again': 19245,
#  'runs': 16320,
#  'single': 111888,
#  'alkaline': 3593,
#  'rechargeable': 39871,
#  'lithium': 24011,
#  'not': 756502,
#  'juice': 7317,
#  'up': 579502,
#  'many': 69798,
#  'needed': 56208,
#  'small': 315496,
#  'also': 178810,
#  'great': 417495,
#  'those': 27240,
#  'road': 38049,
#  'traveling': 12405,
#  'travelling': 4030,
#  'overseas': 3190,
#  'backup': 12119,
#  'maxx': 4797,
#  'kindle': 23681,
#  'fire': 42689,
#  'glacial': 107,
#  'digitally': 2417,
#  'auto': 161421,
#  'make': 257692,
#  'uniquely': 6060,
#  'made': 992152,
#  'impact': 69264,
#  'ergonomic': 28970,
#  'lasting': 80416,
#  'circuitry': 3123,
#  'thin': 64753,
#  'heavy': 154417,
#  'duty': 119066,
#  'shielded': 5022,
#  'due': 46744,
#  'quailty': 302,
#  'wire': 87700,
#  'extending': 2655,
#  'six': 20480,
#  'feet': 170646,
#  'permanent': 18424,
#  'replacement': 251452,
#  'chargers': 7842,
#  'including': 96455,
#  'sony': 46955,
#  'xperia': 10592,
#  'sp': 46127,
#  'developer': 362,
#  'edtion': 40,
#  'perception': 2160,
#  'retractable': 16466,
#  'prevail': 2311,
#  'boost': 15104,
#  'quot': 475256,
#  'button': 642085,
#  'system': 162636,
#  'ergonomically': 6185,
#  'flexible': 106245,
#  'extends': 12674,
#  'final': 6616,
#  'purchase': 196641,
#  'adapter': 115405,
#  'garmin': 9102,
#  'nuvi': 2958,
#  'lmt': 2790,
#  'gps': 23426,
#  'everything': 25035,
#  'need': 116650,
#  'save': 47741,
#  'time': 258852,
#  'sync': 22373,
#  'bundle': 37422,
#  'reduced': 11263,
#  'outlet': 22590,
#  'compacts': 520,
#  'cigarette': 8287,
#  'asus': 18785,
#  'memo': 4462,
#  'pad': 83932,
#  'huawei': 10816,
#  'vision': 20031,
#  'precious': 11313,
#  'swipe': 1076,
#  'enabled': 24632,
#  'guard': 50388,
#  'day': 278280,
#  'screens': 7241,
#  'smaller': 35044,
#  'inches': 1418717,
#  'resolution': 54711,
#  'glare': 29714,
#  'residue': 28587,
#  'card': 274107,
#  'consistent': 17283,
#  'application': 51404,
#  'overlay': 40245,
#  'grid': 55990,
#  'customize': 17206,
#  'easier': 26783,
#  'multiple': 69576,
#  'customizable': 6431,
#  'lm': 12102,
#  'blu': 12946,
#  'evo': 7234,
#  'lte': 15866,
#  'casio': 5517,
#  'gzone': 115,
#  'ravine': 164,
#  'c': 4786357,
#  'jawbone': 1148,
#  'era': 7008,
#  'bluetooth': 88471,
#  'headset': 31665,
#  'line': 220246,
#  'micromax': 72,
#  'last': 185694,
#  'wireless': 96330,
#  'solutions': 7358,
#  'ce': 19530,
#  'certified': 82686,
#  'rubber': 354203,
#  'has': 264271,
#  'easily': 149732,
#  'visible': 102146,
#  'lighted': 6493,
#  'logo': 149964,
#  'indicate': 2733,
#  'source': 23078,
#  'variable': 8709,
#  'impossible': 1760,
#  'overcharge': 1864,
#  'adapters': 10588,
#  'are': 906387,
#  'ideal': 124332,
#  'sources': 4054,
#  'platform': 96519,
#  'supplies': 27372,
#  'addition': 25301,
#  'replenishing': 83,
#  'store': 88636,
#  'sturdy': 65535,
#  'side': 241367,
#  'volts': 9992,
#  'exposed': 7765,
#  'fuse': 9153,
#  'cookie': 117355,
#  'pro': 115011,
#  'knot': 9208,
#  'rabbit': 9565,
#  'cutie': 881,
#  'funny': 42402,
#  'dklmobile': 2,
#  'pcs': 133859,
#  'decorated': 10817,
#  'stickers': 41461,
#  'ipad': 143146,
#  'ipod': 58048,
#  'itouch': 2078,
#  'aluminium': 8142,
#  'sticker': 76151,
#  'compatiable': 639,
#  'withiphone': 13,
#  'gen': 20850,
#  'th': 81754,
#  'nano': 15310,
#  'mini': 227368,
#  'buttome': 2,
#  'come': 78087,
#  'choice': 53908,
#  'powerbear': 19,
#  'reg': 77134,
#  'external': 42499,
#  'studio': 23025,
#  'otg': 4628,
#  'right': 746639,
#  'angle': 57185,
#  'transfer': 38022,
#  'connecting': 9815,
#  'drive': 75393,
#  'flash': 54013,
#  'truly': 11134,
#  'finally': 2641,
#  'outstanding': 12154,
#  'now': 204346,
#  'connect': 38179,
#  'printer': 19164,
#  'plugging': 2130,
#  'instantly': 11885,
#  'role': 15965,
#  'swapping': 1057,
#  'abilities': 1469,
#  'customer': 81961,
#  'want': 52799,
#  'reliability': 23475,
#  'operate': 9802,
#  'peripherals': 1353,
#  'transforms': 2318,
#  'into': 141128,
#  'capable': 7173,
#  'unit': 42805,
#  'buy': 103147,
#  'newest': 8396,
#  'available': 244642,
#  'slimport': 241,
#  'passport': 7344,
#  'mydp': 117,
#  'hdmi': 54697,
#  'play': 120852,
#  'content': 137502,
#  'hdtv': 11681,
#  'connectivity': 9429,
#  'older': 7088,
#  'simply': 55681,
#  'don': 45681,
#  'stable': 21563,
#  'connection': 31511,
#  'works': 65937,
#  'every': 127175,
#  'doesn': 12107,
#  'helps': 63383,
#  'reduce': 44123,
#  'although': 2963,
#  'thanks': 17164,
#  'higher': 19644,
#  'bandwidth': 3478,
#  'supports': 53469,
#  'k': 1196704,
#  'channel': 35757,
#  'audio': 109025,
#  'output': 74662,
#  'genuine': 135741,
#  'professionally': 24191,
#  'gets': 7390,
#  'newly': 3284,
#  'providing': 32155,
#  'enough': 41485,
#  'density': 28954,
#  'three': 89815,
#  'end': 88776,
#  'upgrade': 14036,
#  'sonim': 124,
#  'xp': 22915,
#  'w': 825605,
#  'powerfast': 69,
#  'gives': 50994,
#  'accelerated': 13865,
#  'mah': 56807,
#  'pocket': 254408,
#  'sized': 38776,
#  'securely': 31499,
#  'quicker': 3149,
#  'standard': 193212,
#  'less': 54186,
#  'youre': 9451,
#  'requires': 29869,
#  'control': 167524,
#  'preserve': 11582,
#  'feature': 185384,
#  'oppo': 316,
#  'note': 163993,
#  'adaptive': 2044,
#  'voltages': 524,
#  'faster': 22057,
#  'voltage': 65574,
#  'supported': 21348,
#  'model': 135763,
#  'verify': 6923,
#  'first': 97538,
#  'about': 119458,
#  'if': 1370040,
#  'does': 68376,
#  'still': 20030,
#  'usually': 16109,
#  'stilll': 2,
#  'via': 50585,
#  'aren': 2866,
#  'near': 6610,
#  'results': 24276,
#  'guaranteed': 100561,
#  'cases': 48236,
#  'solar': 36112,
#  'powered': 38828,
#  'moto': 20829,
#  'window': 1112551,
#  'round': 145460,
#  'form': 95496,
#  'sun': 58783,
#  'energy': 52104,
#  'environment': 27803,
#  'well': 111218,
#  'recommended': 63433,
#  'conventional': 5738,
#  'cables': 32494,
#  'charged': 13726,
#  'date': 362306,
#  'simultaneously': 7295,
#  'mac': 70140,
#  'rapidly': 1500,
#  'files': 71087,
#  'female': 34904,
#  'male': 44927,
#  'listed': 28086,
#  'connectors': 30016,
#  'connector': 60679,
#  'nanosecond': 48,
#  'recognization': 50,
#  'chipset': 5526,
#  'length': 790991,
#  'hdx': 3097,
#  'extra': 152363,
#  'maximum': 106228,
#  'portability': 6260,
#  'take': 77108,
#  'office': 71410,
#  'airport': 2097,
#  'anywhere': 32987,
#  'takes': 22053,
#  'maximizes': 4246,
#  'flexibility': 25373,
#  'devicesfor': 2,
#  'reliable': 28252,
#  'click': 142798,
#  'dr': 14656,
#  'dre': 1056,
#  'beats': 4383,
#  'headphones': 37510,
#  'newer': 2727,
#  'hub': 23893,
#  'such': 64188,
#  'keyboards': 2121,
#  'sticks': 14832,
#  'drives': 8806,
#  'mice': 4184,
#  'thumb': 13859,
#  'connected': 11611,
#  'solution': 31478,
#  'user': 41314,
#  'friendly': 91166,
#  'removable': 106119,
#  'storage': 156474,
#  'sharing': 3805,
#  'favorite': 56188,
#  'devices': 81680,
#  'stick': 71720,
#  'enjoy': 51963,
#  'dell': 22477,
#  'venue': 1985,
#  'verizon': 26656,
#  'turbo': 30965,
#  'qualcomm': 1416,
#  'certifed': 116,
#  'voltiq': 13,
#  'ability': 11203,
#  'automatically': 30045,
#  'identifies': 597,
#  'correct': 19474,
#  'current': 30489,
#  'over': 203504,
#  'short': 138910,
#  'circuit': 29277,
#  'risk': 17777,
#  'overheating': 3830,
#  'damaging': 8268,
#  'limited': 98296,
#  'quantity': 38586,
#  'stream': 7856,
#  'shipping': 2291850,
#  ...}

# %%
filenames = os.listdir(r'/data/liufengyuan/NLPinFinance/Filtered Data')
wordlist_title = {}
pat = '[a-zA-Z]+'
total = 0
out = False
for name in filenames:
    f_save = open('/data/liufengyuan/NLPinFinance/Filtered Data/' + name, 'rb')
    print(name)
    file_read = pickle.load(f_save)
    f_save.close()
    for item in file_read:
        total += 1
        sentence = item['title']
        #print(sentence)
        #output = re.findall(pat, sentence.lower())
        #sentence = re.sub(results2, '', sentence)
        #output = tokenize(sentence.lower())
        output = re.findall(pat, sentence.lower())
        #output = []
        #features = item['feature']
        #for fea in features:
        #    if '#A' in fea:
        #        print(fea)
        #        out = True
        #        break
        #    fea = re.sub(results2, '', fea)
            #output.extend(tokenize(fea.lower()))
        #    output.extend(re.findall(pat, fea))
        for word in output:
            if word in wordlist_title.keys():
                wordlist_title[word] += 1
            else:
                wordlist_title[word] = 1
        #if out == True:
        #    out = False
        #    break
    #break
    print(total)
wordlist_title
# Out:
# Cell_Phones_and_Accessories.pkl
# 282198
# Office_Products.pkl
# 417298
# Movies_and_TV.pkl
# 417351
# Patio_Lawn_and_Garden.pkl
# 529729
# Clothing_Shoes_and_Jewelry.pkl
# 2043156
# Electronics.pkl
# 2463881
# Industrial_and_Scientific.pkl
# 2489700
# Kindle_Store.pkl
# 2489700
# Digital_Music.pkl
# 2489723
# Home_and_Kitchen.pkl
# 3026039
# Sports_and_Outdoors.pkl
# 3391802
# CDs_and_Vinyl.pkl
# 3391873
# Books.pkl
# 3392839
# Arts_Crafts_and_Sewing.pkl
# 3505092
# Toys_and_Games.pkl
# 3747531
# Grocery_and_Gourmet_Food.pkl
# 3755740
# AMAZON_FASHION.pkl
# 3764050
# Pet_Supplies.pkl
# 3872506
# Automotive.pkl
# 4291352
# Tools_and_Home_Improvement.pkl
# 4527550
# {}

# %%
'barnes' in words.words()
# Out:
# False

# %%
keyList = list(wordlist.keys())
print(len(keyList))
# Out:
# 845142

# %%
for key in keyList:
    if wordlist[key] <= 30:
        del wordlist[key]

# %%
keyList = list(wordlist.keys())
print(len(keyList))
# Out:
# 71303

# %%
count = 0
for key in keyList:
    count += 1
    if count % 200 == 0:
        print(count)
    if not key in words.words():
        del wordlist[key]
# Out:
# 200
# 400
# 600
# 800
# 1000
# 1200
# 1400
# 1600
# 1800
# 2000
# 2200
# 2400
# 2600
# 2800
# 3000
# 3200
# 3400
# 3600
# 3800
# 4000
# 4200
# 4400
# 4600
# 4800
# 5000
# 5200
# 5400
# 5600
# 5800
# 6000
# 6200
# 6400
# 6600
# 6800
# 7000
# 7200
# 7400
# 7600
# 7800
# 8000
# 8200
# 8400
# 8600
# 8800
# 9000
# 9200
# 9400
# 9600
# 9800
# 10000
# 10200
# 10400
# 10600
# 10800
# 11000
# 11200
# 11400
# 11600
# 11800
# 12000
# 12200
# 12400
# 12600
# 12800
# 13000
# 13200
# 13400
# 13600
# 13800
# 14000
# 14200
# 14400
# 14600
# 14800
# 15000
# 15200
# 15400
# 15600
# 15800
# 16000
# 16200
# 16400
# 16600
# 16800
# 17000
# 17200
# 17400
# 17600
# 17800
# 18000
# 18200
# 18400
# 18600
# 18800
# 19000
# 19200
# 19400
# 19600
# 19800
# 20000
# 20200
# 20400
# 20600
# 20800
# 21000
# 21200
# 21400
# 21600
# 21800
# 22000
# 22200
# 22400
# 22600
# 22800
# 23000
# 23200
# 23400
# 23600
# 23800
# 24000
# 24200
# 24400
# 24600
# 24800
# 25000
# 25200
# 25400
# 25600
# 25800
# 26000
# 26200
# 26400
# 26600
# 26800
# 27000
# 27200
# 27400
# 27600
# 27800
# 28000
# 28200
# 28400
# 28600
# 28800
# 29000
# 29200
# 29400
# 29600
# 29800
# 30000
# 30200
# 30400
# 30600
# 30800
# 31000
# 31200
# 31400
# 31600
# 31800
# 32000
# 32200
# 32400
# 32600
# 32800
# 33000
# 33200
# 33400
# 33600
# 33800
# 34000
# 34200
# 34400
# 34600
# 34800
# 35000
# 35200
# 35400
# 35600
# 35800
# 36000
# 36200
# 36400
# 36600
# 36800
# 37000
# 37200
# 37400
# 37600
# 37800
# 38000
# 38200
# 38400
# 38600
# 38800
# 39000
# 39200
# 39400
# 39600
# 39800
# 40000
# 40200
# 40400
# 40600
# 40800
# 41000
# 41200
# 41400
# 41600
# 41800
# 42000
# 42200
# 42400
# 42600
# 42800
# 43000
# 43200
# 43400
# 43600
# 43800
# 44000
# 44200
# 44400
# 44600
# 44800
# 45000
# 45200
# 45400
# 45600
# 45800
# 46000
# 46200
# 46400
# 46600
# 46800
# 47000
# 47200
# 47400
# 47600
# 47800
# 48000
# 48200
# 48400
# 48600
# 48800
# 49000
# 49200
# 49400
# 49600
# 49800
# 50000
# 50200
# 50400
# 50600
# 50800
# 51000
# 51200
# 51400
# 51600
# 51800
# 52000
# 52200
# 52400
# 52600
# 52800
# 53000
# 53200
# 53400
# 53600
# 53800
# 54000
# 54200
# 54400
# 54600
# 54800
# 55000
# 55200
# 55400
# 55600
# 55800
# 56000
# 56200
# 56400
# 56600
# 56800
# 57000
# 57200
# 57400
# 57600
# 57800
# 58000
# 58200
# 58400
# 58600
# 58800
# 59000
# 59200
# 59400
# 59600
# 59800
# 60000
# 60200
# 60400
# 60600
# 60800
# 61000
# 61200
# 61400
# 61600
# 61800
# 62000
# 62200
# 62400
# 62600
# 62800
# 63000
# 63200
# 63400
# 63600
# 63800
# 64000
# 64200
# 64400
# 64600
# 64800
# 65000
# 65200
# 65400
# 65600
# 65800
# 66000
# 66200
# 66400
# 66600
# 66800
# 67000
# 67200
# 67400
# 67600
# 67800
# 68000
# 68200
# 68400
# 68600
# 68800
# 69000
# 69200
# 69400
# 69600
# 69800
# 70000
# 70200
# 70400
# 70600
# 70800
# 71000
# 71200

# %%
import pandas as pd
wordListFile = pd.DataFrame.from_dict(wordlist, orient='index')

# %%
wordListFile = wordListFile.reset_index().rename(columns={'index': 'word', 0: 'count'})
wordListFile = wordListFile.sort_values(by=['word'], ignore_index=True)
wordListFile = wordListFile[wordListFile['count'] > 30]
wordListFile
# Out:
#               word     count
# 0                a  14740565
# 1               aa     79082
# 2              aam        31
# 3              aba      1370
# 4            abaca       116
# ...            ...       ...
# 21469         zoom     32406
# 21470  zooplankton        40
# 21471        zorro       140
# 21472     zucchini       701
# 21473         zyme        45
#
# [21474 rows x 2 columns]

# %%
wordListFile.to_csv('WordList.csv', index=False)

# %%
wordListFile.head(60)
# Out:
#              word     count
# 0               a  14740565
# 1              aa     79082
# 2             aam        31
# 3             aba      1370
# 4           abaca       116
# 5          abacus       602
# 6         abalone      1735
# 7         abandon        99
# 8       abandoned        85
# 9            abas        34
# 10      abatement       226
# 11            abb       154
# 12          abbey      1131
# 13          abbot        48
# 14   abbreviation        38
# 15        abdomen       800
# 16      abdominal      1176
# 17      abduction        33
# 18     aberration       372
# 19          abide        71
# 20        abigail       194
# 21        ability     11203
# 22         ablaze        51
# 23           able     22506
# 24           ably        31
# 25       abnormal      1223
# 26         aboard       332
# 27          abode        40
# 28     abominable        51
# 29     aboriginal        47
# 30         abound        59
# 31          about    119458
# 32          above     45920
# 33    aboveground       101
# 34       abrasion     17458
# 35       abrasive      4047
# 36         abroad       713
# 37         abrupt        41
# 38        absence       271
# 39         absent        38
# 40       absinthe       117
# 41       absolute    249238
# 42     absolutely     13991
# 43         absorb     12293
# 44  absorbability        51
# 45     absorbable       704
# 46       absorbed       939
# 47     absorbency      1548
# 48      absorbent     16549
# 49       absorber      3474
# 50      absorbing     21952
# 51     absorption     18763
# 52     absorptive       249
# 53     abstinence        32
# 54       abstract      6285
# 55    abstraction        52
# 56            abu       261
# 57      abundance       457
# 58       abundant       659
# 59     abundantly        63

# %%
print(wordListFile['count'].sum())
wordListFile.to_csv('WordList.csv')
# Out:
# 422130557

# %% [markdown]
# ## 'asin','title','feature','imageURLHighRes'

# %%
# 依据条件筛选数据
filenames = os.listdir(r'/data/liufengyuan/NLPinFinance/Data')
total = 0
for name in filenames:

    data = {}
    filename_path = os.path.join(r'/data/liufengyuan/NLPinFinance/Data',name)
    category = re.findall('meta_(.*?).json.gz',name)[0]
    data[category] = []

    with gzip.open(filename_path) as f:

        count = 0
        for l in f:
            count += 1
            pre_data = json.loads(l.strip())
            if 'imageURLHighRes' in pre_data.keys() and 'feature' in pre_data.keys() and 'description' in pre_data.keys() and 'title' in pre_data.keys() and 'asin' in pre_data.keys():
                if len(pre_data['imageURLHighRes']) != 0 and len(pre_data['description']) != 0 and len(pre_data['feature']) != 0 and len(pre_data['title']) != 0 and len(pre_data['asin']) != 0:
                    data[category].append({k : pre_data[k] for k in ('asin','title','feature', 'description', 'imageURLHighRes')})

    print(f'{category}中满足条件的共{len(data[category])}条,占比{round(100*len(data[category])/count,2)}%')
    total += len(data[category])
    # 字典保存
    path = os.path.join(r'/data/liufengyuan/NLPinFinance/Filtered Data',category)
    f_save = open(path + '.pkl', 'wb')
    pickle.dump(data[category], f_save)
    f_save.close() # 1276549
print(total)
# Out:
# Tools_and_Home_Improvement中满足条件的共236198条,占比41.33%
# AMAZON_FASHION中满足条件的共8310条,占比4.45%
# Office_Products中满足条件的共135100条,占比42.83%
# Pet_Supplies中满足条件的共108456条,占比52.65%
# Industrial_and_Scientific中满足条件的共25819条,占比15.42%
# Toys_and_Games中满足条件的共242439条,占比38.25%
# Arts_Crafts_and_Sewing中满足条件的共112253条,占比37.05%
# Kindle_Store中满足条件的共0条,占比0.0%
# CDs_and_Vinyl中满足条件的共71条,占比0.01%
# Sports_and_Outdoors中满足条件的共365763条,占比38.01%
# Automotive中满足条件的共418846条,占比44.97%
# Cell_Phones_and_Accessories中满足条件的共282198条,占比47.82%
# Books中满足条件的共966条,占比0.03%
# Patio_Lawn_and_Garden中满足条件的共112378条,占比40.21%
# Home_and_Kitchen中满足条件的共536316条,占比41.24%
# Clothing_Shoes_and_Jewelry中满足条件的共1513427条,占比56.36%
# Electronics中满足条件的共420725条,占比53.5%
# Movies_and_TV中满足条件的共53条,占比0.03%
# Grocery_and_Gourmet_Food中满足条件的共8209条,占比2.86%
# Digital_Music中满足条件的共23条,占比0.03%
# 4527550
