# %%
import pickle
from my_build_vocab import Vocabulary
my_vocab = pickle.load(open('/home/liufengyuan/NLPinFinance/Experiment/my_vocab.pkl','rb'))

# %%
my_vocab.word2idx
# Out:
# {'<pad>': 0,
#  '<start>': 1,
#  '<end>': 2,
#  '<unk>': 3,
#  'a': 4,
#  'aa': 5,
#  'aam': 6,
#  'aba': 7,
#  'abaca': 8,
#  'abacus': 9,
#  'abalone': 10,
#  'abandon': 11,
#  'abandoned': 12,
#  'abas': 13,
#  'abatement': 14,
#  'abb': 15,
#  'abbey': 16,
#  'abbot': 17,
#  'abbreviation': 18,
#  'abdomen': 19,
#  'abdominal': 20,
#  'abduction': 21,
#  'aberration': 22,
#  'abide': 23,
#  'abigail': 24,
#  'ability': 25,
#  'ablaze': 26,
#  'able': 27,
#  'ably': 28,
#  'abnormal': 29,
#  'aboard': 30,
#  'abode': 31,
#  'abominable': 32,
#  'aboriginal': 33,
#  'abound': 34,
#  'about': 35,
#  'above': 36,
#  'aboveground': 37,
#  'abrasion': 38,
#  'abrasive': 39,
#  'abroad': 40,
#  'abrupt': 41,
#  'absence': 42,
#  'absent': 43,
#  'absinthe': 44,
#  'absolute': 45,
#  'absolutely': 46,
#  'absorb': 47,
#  'absorbability': 48,
#  'absorbable': 49,
#  'absorbed': 50,
#  'absorbency': 51,
#  'absorbent': 52,
#  'absorber': 53,
#  'absorbing': 54,
#  'absorption': 55,
# ...

# %%
my_vocab.idx2word
# Out:
# {0: '<pad>',
#  1: '<start>',
#  2: '<end>',
#  3: '<unk>',
#  4: 'a',
#  5: 'aa',
#  6: 'aam',
#  7: 'aba',
#  8: 'abaca',
#  9: 'abacus',
#  10: 'abalone',
#  11: 'abandon',
#  12: 'abandoned',
#  13: 'abas',
#  14: 'abatement',
#  15: 'abb',
#  16: 'abbey',
#  17: 'abbot',
#  18: 'abbreviation',
#  19: 'abdomen',
#  20: 'abdominal',
#  21: 'abduction',
#  22: 'aberration',
#  23: 'abide',
#  24: 'abigail',
#  25: 'ability',
#  26: 'ablaze',
#  27: 'able',
#  28: 'ably',
#  29: 'abnormal',
#  30: 'aboard',
#  31: 'abode',
#  32: 'abominable',
#  33: 'aboriginal',
#  34: 'abound',
#  35: 'about',
#  36: 'above',
#  37: 'aboveground',
#  38: 'abrasion',
#  39: 'abrasive',
#  40: 'abroad',
#  41: 'abrupt',
#  42: 'absence',
#  43: 'absent',
#  44: 'absinthe',
#  45: 'absolute',
#  46: 'absolutely',
#  47: 'absorb',
#  48: 'absorbability',
#  49: 'absorbable',
#  50: 'absorbed',
#  51: 'absorbency',
#  52: 'absorbent',
#  53: 'absorber',
#  54: 'absorbing',
#  55: 'absorption',
# ...
