# %%
import pickle
import json
combine = json.load(open('/data/liufengyuan/NLPinFinance/Combined_Data.json','r'))

# %%
for idx, ele in enumerate(combine):
    if idx > 100000 and idx < 100100:
        print(ele['title'])
        print('\n')
# Out:
# Milano Screen Protector Cover, MPERO Collection 3 Pack of Matte Anti-Glare Screen Protectors for Kyocera Milano C5120
#
#
# Samsung Galaxy Trend 3 Screen Protector Cover, MPERO Collection 5 Pack of Clear Screen Protectors for Samsung Galaxy Trend 3
#
#
# Gravity Q Screen Protector Cover, MPERO Collection 3 Pack of Matte Anti-Glare Screen Protectors for Samsung Gravity Q T289
#
#
# Importer520 (TM) Rubber Soft Flexible Plaid Pattern TPU Gel Skin Cover Case For Straight Talk Net 10 ZTE Majesty 796C - Hot Pink
#
#
# LG Enact Screen Protector Cover, MPERO Collection 5 Pack of Clear Screen Protectors for LG Enact VS890
#
#
# MPERO Collection 3 Pack of Matte Anti-Glare Screen Protectors for ZTE Warp Sequent N861
#
#
# MPERO Collection 3 Pack of Matte Anti-Glare Screen Protectors for Huawei Vitria
#
#
# MPERO Collection 5 Pack of Clear Screen Protectors for ZTE Warp Sequent N861
#
#
# ...

# %%
list = 'I am Junyi Wang'

# %%
list.split()
# Out:
# ['I', 'am', 'Junyi', 'Wang']
